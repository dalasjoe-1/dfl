# %% [markdown]
# <a href="https://colab.research.google.com/github/dalasjoe-1/dfl/blob/master/DFL_Colab_1.0_2020.12.27.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ALL - Extract, Convert and MP4

# %%
import IPython
from google.colab import output

display(IPython.display.Javascript('''
 function ClickConnect(){
   btn = document.querySelector("colab-connect-button")
   if (btn != null){
     console.log("Click colab-connect-button"); 
     btn.click() 
     }
   
   btn = document.getElementById('ok')
   if (btn != null){
     console.log("Click reconnect"); 
     btn.click() 
     }
  }
  
setInterval(ClickConnect,60000)
'''))

print("Done.")

#@title Import from Drive

Mode = "workspace" #@param ["workspace", "data_src", "data_dst", "data_src aligned", "data_dst aligned", "models"]
Archive_name = "workspace.zip" #@param {type:"string"}

#Mount Google Drive as folder
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

def zip_and_copy(path, mode):
  unzip_cmd=" -q "+Archive_name
  
  # %cd $path
  copy_cmd = "/content/drive/My\ Drive/"+Archive_name+" "+path
  # !cp $copy_cmd
  # !unzip $unzip_cmd    
  # !rm $Archive_name

if Mode == "workspace":
  zip_and_copy("/content", "workspace")
elif Mode == "data_src":
  zip_and_copy("/content/workspace", "data_src")
elif Mode == "data_dst":
  zip_and_copy("/content/workspace", "data_dst")
elif Mode == "data_src aligned":
  zip_and_copy("/content/workspace/data_src", "aligned")
elif Mode == "data_dst aligned":
  zip_and_copy("/content/workspace/data_dst", "aligned")
elif Mode == "models":
  zip_and_copy("/content/workspace", "model")
  
print("Done!")

#@title Clone or pull DeepFaceLab from Github

Mode = "clone" #@param ["clone", "pull"]

from pathlib import Path
if (Mode == "clone"):
  # !git clone https://github.com/iperov/DeepFaceLab.git --branch DFL-1.0
else:
  # %cd /content/DeepFaceLab
  # !git pull

# !pip uninstall -y tensorflow
# !pip install -r /content/DeepFaceLab/requirements-colab.txt
# !pip install --upgrade scikit-image
# !apt-get install cuda-10-0

if not Path("/content/pretrain").exists():
  # !wget -q --no-check-certificate -r 'https://github.com/chervonij/DFL-Colab/releases/download/pretrain-CelebA/pretrain_CelebA.zip' -O pretrain_CelebA.zip
  # !mkdir /content/pretrain
  # !unzip -q /content/pretrain_CelebA.zip -d /content/pretrain/
  # !rm /content/pretrain_CelebA.zip

# print("Done!")

#@title Extract frames
Video = "data_dst" #@param ["data_src", "data_dst"]

# %cd "/content"

cmd = "DeepFaceLab/main.py videoed extract-video"

if Video == "data_dst":
  cmd+= " --input-file workspace/data_dst.* --output-dir workspace/data_dst/"
else:
  cmd+= " --input-file workspace/data_src.* --output-dir workspace/data_src/"
  
# !python $cmd

#@title Convert
Model = "LIAEF128" #@param ["SAEHD", "SAE", "Quick96", "H128", "LIAEF128", "DF", "AVATAR" ]

if Model == "AVATAR":  
  cmd = "DeepFaceLab/main.py convert --input-dir workspace/data_dst/aligned --output-dir workspace/data_dst/merged --model-dir workspace/model --model "+Model
else:
  cmd = "DeepFaceLab/main.py convert --input-dir workspace/data_dst --output-dir workspace/data_dst/merged --aligned-dir workspace/data_dst/aligned --model-dir workspace/model --model "+Model

# %cd "/content"
# !python $cmd

#@title Get result video and copy to Drive 

fileName = "eun_norm2_LIAEF_seamless_learned-dst-prd_20_200_scale-1_rct_sharp0.mp4"



# !python DeepFaceLab/main.py videoed video-from-sequence --input-dir workspace/data_dst/merged --output-file workspace/$fileName --reference-file workspace/data_dst.mp4 --bitrate 16
# !cp /content/workspace/$fileName /content/drive/My\ Drive/
# Out:
# Converting:  44% 731/1653 [34:36<43:39,  2.84s/it]
#
# no faces found for 00733.png, copying without faces
# Converting:  44% 733/1653 [34:38<43:28,  2.84s/it]
#
# no faces found for 00734.png, copying without faces
#
#
# no faces found for 00735.png, copying without faces
# Converting:  44% 735/1653 [34:38<43:16,  2.83s/it]
#
# no faces found for 00736.png, copying without faces
#
#
# no faces found for 00737.png, copying without faces
# Converting:  45% 737/1653 [34:38<43:03,  2.82s/it]
#
# no faces found for 00738.png, copying without faces
#
#
# no faces found for 00739.png, copying without faces
# Converting:  45% 739/1653 [34:38<42:50,  2.81s/it]
#
# no faces found for 00740.png, copying without faces
#
#
# no faces found for 00741.png, copying without faces
# Converting:  45% 741/1653 [34:38<42:38,  2.81s/it]
#
# no faces found for 00742.png, copying without faces
#
#
# no faces found for 00743.png, copying without faces
# Converting:  45% 743/1653 [34:38<42:25,  2.80s/it]
#
# no faces found for 00744.png, copying without faces
#
#
# no faces found for 00745.png, copying without faces
# Converting:  45% 745/1653 [34:38<42:13,  2.79s/it]
#
# no faces found for 00746.png, copying without faces
#
#
# no faces found for 00747.png, copying without faces
# Converting:  45% 747/1653 [34:38<42:01,  2.78s/it]
#
# no faces found for 00748.png, copying without faces
#
#
# no faces found for 00749.png, copying without faces
# Converting:  45% 749/1653 [34:38<41:49,  2.78s/it]
#
# no faces found for 00750.png, copying without faces
#
#
# no faces found for 00751.png, copying without faces
# Converting:  45% 751/1653 [34:38<41:36,  2.77s/it]
#
# no faces found for 00752.png, copying without faces
#
#
# no faces found for 00753.png, copying without faces
# Converting:  46% 753/1653 [34:38<41:24,  2.76s/it]
#
# no faces found for 00754.png, copying without faces
#
#
# no faces found for 00755.png, copying without faces
# Converting:  46% 755/1653 [34:38<41:12,  2.75s/it]
#
# no faces found for 00756.png, copying without faces
#
#
# no faces found for 00757.png, copying without faces
# Converting:  46% 757/1653 [34:39<41:00,  2.75s/it]
#
# no faces found for 00758.png, copying without faces
#
#
# no faces found for 00759.png, copying without faces
# Converting:  46% 759/1653 [34:39<40:48,  2.74s/it]
#
# no faces found for 00760.png, copying without faces
#
#
# no faces found for 00761.png, copying without faces
# Converting:  46% 761/1653 [34:39<40:36,  2.73s/it]
#
# no faces found for 00762.png, copying without faces
#
#
# no faces found for 00763.png, copying without faces
# Converting:  46% 763/1653 [34:39<40:25,  2.72s/it]
#
# no faces found for 00764.png, copying without faces
#
#
# no faces found for 00765.png, copying without faces
# Converting:  46% 765/1653 [34:39<40:13,  2.72s/it]
#
# no faces found for 00766.png, copying without faces
#
#
# no faces found for 00767.png, copying without faces
# Converting:  46% 767/1653 [34:39<40:01,  2.71s/it]
#
# no faces found for 00768.png, copying without faces
#
#
# no faces found for 00769.png, copying without faces
# Converting:  47% 769/1653 [34:39<39:50,  2.70s/it]
#
# no faces found for 00770.png, copying without faces
#
#
# no faces found for 00771.png, copying without faces
# Converting:  47% 771/1653 [34:39<39:38,  2.70s/it]
#
# no faces found for 00772.png, copying without faces
#
#
# no faces found for 00773.png, copying without faces
# Converting:  47% 773/1653 [34:39<39:27,  2.69s/it]
#
# no faces found for 00774.png, copying without faces
#
#
# no faces found for 00775.png, copying without faces
# Converting:  47% 774/1653 [34:39<39:21,  2.69s/it]
#
# no faces found for 00776.png, copying without faces
# Converting:  47% 775/1653 [34:39<39:15,  2.68s/it]
#
# no faces found for 00777.png, copying without faces
# Converting:  47% 776/1653 [34:39<39:10,  2.68s/it]
#
# no faces found for 00778.png, copying without faces
# Converting:  47% 777/1653 [34:39<39:04,  2.68s/it]
#
# no faces found for 00779.png, copying without faces
# Converting:  47% 778/1653 [34:39<38:58,  2.67s/it]
#
# no faces found for 00780.png, copying without faces
# Converting:  47% 779/1653 [34:39<38:52,  2.67s/it]
#
# no faces found for 00781.png, copying without faces
# Converting:  47% 780/1653 [34:39<38:47,  2.67s/it]
#
# no faces found for 00782.png, copying without faces
# Converting:  47% 781/1653 [34:39<38:41,  2.66s/it]
#
# no faces found for 00783.png, copying without faces
# Converting:  47% 782/1653 [34:39<38:36,  2.66s/it]
#
# no faces found for 00784.png, copying without faces
# Converting:  47% 783/1653 [34:39<38:30,  2.66s/it]
#
# no faces found for 00785.png, copying without faces
# Converting:  47% 784/1653 [34:39<38:24,  2.65s/it]
#
# no faces found for 00786.png, copying without faces
# Converting:  47% 785/1653 [34:39<38:19,  2.65s/it]
#
# no faces found for 00787.png, copying without faces
# Converting:  48% 786/1653 [34:39<38:13,  2.65s/it]
#
# no faces found for 00788.png, copying without faces
# Converting:  48% 787/1653 [34:39<38:08,  2.64s/it]
#
# no faces found for 00789.png, copying without faces
# Converting:  48% 788/1653 [34:39<38:02,  2.64s/it]
#
# no faces found for 00790.png, copying without faces
# Converting:  48% 789/1653 [34:39<37:57,  2.64s/it]
#
# no faces found for 00791.png, copying without faces
# Converting:  48% 790/1653 [34:39<37:51,  2.63s/it]
#
# no faces found for 00792.png, copying without faces
# Converting:  48% 791/1653 [34:39<37:46,  2.63s/it]
#
# no faces found for 00793.png, copying without faces
# Converting:  48% 792/1653 [34:39<37:40,  2.63s/it]
#
# no faces found for 00794.png, copying without faces
# Converting:  48% 793/1653 [34:39<37:35,  2.62s/it]
#
# no faces found for 00795.png, copying without faces
# Converting:  48% 794/1653 [34:39<37:29,  2.62s/it]
#
# no faces found for 00796.png, copying without faces
# Converting:  48% 795/1653 [34:39<37:24,  2.62s/it]
#
# no faces found for 00797.png, copying without faces
# Converting:  48% 796/1653 [34:39<37:19,  2.61s/it]
#
# no faces found for 00798.png, copying without faces
# Converting:  48% 797/1653 [34:39<37:13,  2.61s/it]
#
# no faces found for 00799.png, copying without faces
# Converting:  48% 798/1653 [34:39<37:08,  2.61s/it]
#
# no faces found for 00800.png, copying without faces
# Converting:  48% 799/1653 [34:39<37:02,  2.60s/it]
#
# no faces found for 00801.png, copying without faces
# Converting:  48% 800/1653 [34:39<36:57,  2.60s/it]
#
# no faces found for 00802.png, copying without faces
# Converting:  48% 801/1653 [34:39<36:52,  2.60s/it]
#
# no faces found for 00803.png, copying without faces
# Converting:  49% 802/1653 [34:39<36:46,  2.59s/it]
#
# no faces found for 00804.png, copying without faces
# Converting:  49% 803/1653 [34:39<36:41,  2.59s/it]
#
# no faces found for 00805.png, copying without faces
# Converting:  49% 804/1653 [34:39<36:36,  2.59s/it]
#
# no faces found for 00806.png, copying without faces
# Converting:  49% 805/1653 [34:39<36:30,  2.58s/it]
#
# no faces found for 00807.png, copying without faces
# Converting:  49% 806/1653 [34:39<36:25,  2.58s/it]
#
# no faces found for 00808.png, copying without faces
# Converting:  49% 807/1653 [34:39<36:20,  2.58s/it]
#
# no faces found for 00809.png, copying without faces
# Converting:  49% 808/1653 [34:39<36:15,  2.57s/it]
#
# no faces found for 00810.png, copying without faces
# Converting:  49% 809/1653 [34:39<36:09,  2.57s/it]
#
# no faces found for 00811.png, copying without faces
# Converting:  49% 810/1653 [34:39<36:04,  2.57s/it]
#
# no faces found for 00812.png, copying without faces
# Converting:  49% 811/1653 [34:39<35:59,  2.56s/it]
#
# no faces found for 00813.png, copying without faces
# Converting:  49% 812/1653 [34:39<35:54,  2.56s/it]
#
# no faces found for 00814.png, copying without faces
# Converting:  49% 813/1653 [34:39<35:48,  2.56s/it]
#
# no faces found for 00815.png, copying without faces
# Converting:  49% 814/1653 [34:39<35:43,  2.56s/it]
#
# no faces found for 00816.png, copying without faces
# Converting:  49% 815/1653 [34:39<35:38,  2.55s/it]
#
# no faces found for 00817.png, copying without faces
# Converting:  49% 816/1653 [34:39<35:33,  2.55s/it]
#
# no faces found for 00818.png, copying without faces
# Converting:  49% 817/1653 [34:39<35:28,  2.55s/it]
#
# no faces found for 00819.png, copying without faces
# Converting:  49% 818/1653 [34:39<35:23,  2.54s/it]
#
# no faces found for 00820.png, copying without faces
# Converting:  50% 819/1653 [34:39<35:18,  2.54s/it]
#
# no faces found for 00821.png, copying without faces
# Converting:  50% 820/1653 [34:39<35:12,  2.54s/it]
#
# no faces found for 00822.png, copying without faces
# Converting:  50% 821/1653 [34:40<35:07,  2.53s/it]
#
# no faces found for 00823.png, copying without faces
# Converting:  50% 822/1653 [34:40<35:02,  2.53s/it]
#
# no faces found for 00824.png, copying without faces
# Converting:  50% 823/1653 [34:40<34:57,  2.53s/it]
#
# no faces found for 00825.png, copying without faces
# Converting:  50% 824/1653 [34:40<34:52,  2.52s/it]
#
# no faces found for 00826.png, copying without faces
# Converting:  50% 825/1653 [34:40<34:47,  2.52s/it]
#
# no faces found for 00827.png, copying without faces
# Converting:  50% 826/1653 [34:40<34:42,  2.52s/it]
#
# no faces found for 00828.png, copying without faces
# Converting:  50% 827/1653 [34:40<34:37,  2.52s/it]
#
# no faces found for 00829.png, copying without faces
# Converting:  50% 828/1653 [34:40<34:32,  2.51s/it]
#
# no faces found for 00830.png, copying without faces
# Converting:  50% 829/1653 [34:40<34:27,  2.51s/it]
#
# no faces found for 00831.png, copying without faces
# Converting:  50% 830/1653 [34:40<34:22,  2.51s/it]
#
# no faces found for 00832.png, copying without faces
# Converting:  50% 831/1653 [34:40<34:17,  2.50s/it]
#
# no faces found for 00833.png, copying without faces
# Converting:  50% 832/1653 [34:40<34:12,  2.50s/it]
#
# no faces found for 00834.png, copying without faces
# Converting:  50% 833/1653 [34:40<34:07,  2.50s/it]
#
# no faces found for 00835.png, copying without faces
# Converting:  50% 834/1653 [34:40<34:02,  2.49s/it]
#
# no faces found for 00836.png, copying without faces
# Converting:  51% 835/1653 [34:40<33:57,  2.49s/it]
#
# no faces found for 00837.png, copying without faces
# Converting:  51% 836/1653 [34:40<33:52,  2.49s/it]
#
# no faces found for 00838.png, copying without faces
# Converting:  51% 837/1653 [34:40<33:48,  2.49s/it]
#
# no faces found for 00839.png, copying without faces
# Converting:  51% 838/1653 [34:40<33:43,  2.48s/it]
#
# no faces found for 00840.png, copying without faces
# Converting:  51% 839/1653 [34:40<33:38,  2.48s/it]
#
# no faces found for 00841.png, copying without faces
# Converting:  51% 840/1653 [34:40<33:33,  2.48s/it]
#
# no faces found for 00842.png, copying without faces
# Converting:  51% 841/1653 [34:40<33:28,  2.47s/it]
#
# no faces found for 00843.png, copying without faces
# Converting:  51% 842/1653 [34:40<33:23,  2.47s/it]
#
# no faces found for 00844.png, copying without faces
# Converting:  51% 843/1653 [34:40<33:18,  2.47s/it]
#
# no faces found for 00845.png, copying without faces
# Converting:  51% 844/1653 [34:40<33:14,  2.46s/it]
#
# no faces found for 00846.png, copying without faces
# Converting:  51% 845/1653 [34:40<33:09,  2.46s/it]
#
# no faces found for 00847.png, copying without faces
# Converting:  51% 846/1653 [34:40<33:04,  2.46s/it]
#
# no faces found for 00848.png, copying without faces
# Converting:  51% 848/1653 [34:40<32:54,  2.45s/it]
#
# no faces found for 00849.png, copying without faces
#
#
# no faces found for 00850.png, copying without faces
# Converting:  51% 850/1653 [34:40<32:45,  2.45s/it]
#
# no faces found for 00851.png, copying without faces
#
#
# no faces found for 00852.png, copying without faces
# Converting:  52% 852/1653 [34:40<32:36,  2.44s/it]
#
# no faces found for 00853.png, copying without faces
#
#
# no faces found for 00854.png, copying without faces
# Converting:  52% 854/1653 [34:40<32:26,  2.44s/it]
#
# no faces found for 00855.png, copying without faces
#
#
# no faces found for 00856.png, copying without faces
# Converting:  52% 856/1653 [34:40<32:17,  2.43s/it]
#
# no faces found for 00857.png, copying without faces
#
#
# no faces found for 00858.png, copying without faces
# Converting:  52% 858/1653 [34:40<32:07,  2.43s/it]
#
# no faces found for 00859.png, copying without faces
#
#
# no faces found for 00860.png, copying without faces
# Converting:  52% 860/1653 [34:40<31:58,  2.42s/it]
#
# no faces found for 00861.png, copying without faces
#
#
# no faces found for 00862.png, copying without faces
# Converting:  52% 862/1653 [34:40<31:49,  2.41s/it]
#
# no faces found for 00863.png, copying without faces
#
#
# no faces found for 00864.png, copying without faces
# Converting:  52% 864/1653 [34:40<31:40,  2.41s/it]
#
# no faces found for 00865.png, copying without faces
#
#
# no faces found for 00866.png, copying without faces
# Converting:  52% 866/1653 [34:40<31:30,  2.40s/it]
#
# no faces found for 00867.png, copying without faces
#
#
# no faces found for 00868.png, copying without faces
# Converting:  53% 868/1653 [34:40<31:21,  2.40s/it]
#
# no faces found for 00869.png, copying without faces
#
#
# no faces found for 00870.png, copying without faces
# Converting:  53% 869/1653 [34:40<31:17,  2.39s/it]
#
# no faces found for 00871.png, copying without faces
# Converting:  53% 870/1653 [34:40<31:12,  2.39s/it]
#
# no faces found for 00872.png, copying without faces
# Converting:  53% 871/1653 [34:40<31:08,  2.39s/it]
#
# no faces found for 00873.png, copying without faces
# Converting:  53% 872/1653 [34:40<31:03,  2.39s/it]
#
# no faces found for 00874.png, copying without faces
# Converting:  53% 873/1653 [34:40<30:59,  2.38s/it]
#
# no faces found for 00875.png, copying without faces
# Converting:  53% 874/1653 [34:40<30:54,  2.38s/it]
#
# no faces found for 00876.png, copying without faces
# Converting:  53% 875/1653 [34:40<30:50,  2.38s/it]
#
# no faces found for 00877.png, copying without faces
# Converting:  53% 876/1653 [34:40<30:45,  2.38s/it]
#
# no faces found for 00878.png, copying without faces
# Converting:  53% 877/1653 [34:40<30:41,  2.37s/it]
#
# no faces found for 00879.png, copying without faces
# Converting:  53% 878/1653 [34:40<30:36,  2.37s/it]
#
# no faces found for 00880.png, copying without faces
# Converting:  53% 879/1653 [34:40<30:32,  2.37s/it]
#
# no faces found for 00881.png, copying without faces
# Converting:  53% 880/1653 [34:41<30:27,  2.36s/it]
#
# no faces found for 00882.png, copying without faces
# Converting:  53% 881/1653 [34:41<30:23,  2.36s/it]
#
# no faces found for 00883.png, copying without faces
# Converting:  53% 882/1653 [34:41<30:19,  2.36s/it]
#
# no faces found for 00884.png, copying without faces
# Converting:  53% 883/1653 [34:41<30:14,  2.36s/it]
#
# no faces found for 00885.png, copying without faces
# Converting:  53% 884/1653 [34:41<30:10,  2.35s/it]
#
# no faces found for 00886.png, copying without faces
# Converting:  54% 885/1653 [34:41<30:05,  2.35s/it]
#
# no faces found for 00887.png, copying without faces
# Converting:  54% 886/1653 [34:41<30:01,  2.35s/it]
#
# no faces found for 00888.png, copying without faces
# Converting:  54% 887/1653 [34:41<29:57,  2.35s/it]
#
# no faces found for 00889.png, copying without faces
# Converting:  54% 888/1653 [34:41<29:52,  2.34s/it]
#
# no faces found for 00890.png, copying without faces
# Converting:  54% 889/1653 [34:41<29:48,  2.34s/it]
#
# no faces found for 00891.png, copying without faces
# Converting:  54% 890/1653 [34:41<29:44,  2.34s/it]
#
# no faces found for 00892.png, copying without faces
# Converting:  54% 891/1653 [34:41<29:39,  2.34s/it]
#
# no faces found for 00893.png, copying without faces
# Converting:  54% 892/1653 [34:41<29:35,  2.33s/it]
#
# no faces found for 00894.png, copying without faces
# Converting:  54% 893/1653 [34:41<29:31,  2.33s/it]
#
# no faces found for 00895.png, copying without faces
# Converting:  54% 894/1653 [34:41<29:26,  2.33s/it]
#
# no faces found for 00896.png, copying without faces
# Converting:  54% 896/1653 [34:41<29:18,  2.32s/it]
#
# no faces found for 00897.png, copying without faces
#
#
# no faces found for 00898.png, copying without faces
# Converting:  54% 898/1653 [34:41<29:09,  2.32s/it]
#
# no faces found for 00899.png, copying without faces
#
#
# no faces found for 00900.png, copying without faces
# Converting:  54% 900/1653 [34:41<29:01,  2.31s/it]
#
# no faces found for 00901.png, copying without faces
#
#
# no faces found for 00902.png, copying without faces
# Converting:  55% 902/1653 [34:41<28:52,  2.31s/it]
#
# no faces found for 00903.png, copying without faces
#
#
# no faces found for 00904.png, copying without faces
# Converting:  55% 904/1653 [34:41<28:44,  2.30s/it]
#
# no faces found for 00905.png, copying without faces
#
#
# no faces found for 00906.png, copying without faces
# Converting:  55% 906/1653 [34:41<28:36,  2.30s/it]
#
# no faces found for 00907.png, copying without faces
#
#
# no faces found for 00908.png, copying without faces
# Converting:  55% 907/1653 [34:41<28:32,  2.29s/it]
#
# no faces found for 00909.png, copying without faces
# Converting:  55% 908/1653 [34:41<28:27,  2.29s/it]
#
# no faces found for 00910.png, copying without faces
# Converting:  55% 909/1653 [34:41<28:23,  2.29s/it]
#
# no faces found for 00911.png, copying without faces
# Converting:  55% 910/1653 [34:41<28:19,  2.29s/it]
#
# no faces found for 00912.png, copying without faces
# Converting:  55% 911/1653 [34:41<28:15,  2.28s/it]
#
# no faces found for 00913.png, copying without faces
# Converting:  55% 912/1653 [34:41<28:11,  2.28s/it]
#
# no faces found for 00914.png, copying without faces
# Converting:  55% 913/1653 [34:41<28:07,  2.28s/it]
#
# no faces found for 00915.png, copying without faces
# Converting:  55% 914/1653 [34:41<28:03,  2.28s/it]
#
# no faces found for 00916.png, copying without faces
# Converting:  55% 915/1653 [34:41<27:58,  2.27s/it]
#
# no faces found for 00917.png, copying without faces
# Converting:  55% 916/1653 [34:41<27:54,  2.27s/it]
#
# no faces found for 00918.png, copying without faces
# Converting:  55% 917/1653 [34:41<27:50,  2.27s/it]
#
# no faces found for 00919.png, copying without faces
# Converting:  56% 918/1653 [34:41<27:46,  2.27s/it]
#
# no faces found for 00920.png, copying without faces
# Converting:  56% 919/1653 [34:41<27:42,  2.27s/it]
#
# no faces found for 00921.png, copying without faces
# Converting:  56% 920/1653 [34:41<27:38,  2.26s/it]
#
# no faces found for 00922.png, copying without faces
# Converting:  56% 921/1653 [34:41<27:34,  2.26s/it]
#
# no faces found for 00923.png, copying without faces
# Converting:  56% 922/1653 [34:41<27:30,  2.26s/it]
#
# no faces found for 00924.png, copying without faces
# Converting:  56% 923/1653 [34:41<27:26,  2.26s/it]
#
# no faces found for 00925.png, copying without faces
# Converting:  56% 924/1653 [34:41<27:22,  2.25s/it]
#
# no faces found for 00926.png, copying without faces
# Converting:  56% 925/1653 [34:41<27:18,  2.25s/it]
#
# no faces found for 00927.png, copying without faces
# Converting:  56% 926/1653 [34:41<27:14,  2.25s/it]
#
# no faces found for 00928.png, copying without faces
# Converting:  56% 927/1653 [34:41<27:10,  2.25s/it]
#
# no faces found for 00929.png, copying without faces
# Converting:  56% 928/1653 [34:41<27:06,  2.24s/it]
#
# no faces found for 00930.png, copying without faces
# Converting:  56% 929/1653 [34:41<27:02,  2.24s/it]
#
# no faces found for 00931.png, copying without faces
# Converting:  56% 930/1653 [34:41<26:58,  2.24s/it]
#
# no faces found for 00932.png, copying without faces
# Converting:  56% 931/1653 [34:41<26:54,  2.24s/it]
#
# no faces found for 00933.png, copying without faces
# Converting:  56% 932/1653 [34:41<26:50,  2.23s/it]
#
# no faces found for 00934.png, copying without faces
# Converting:  56% 933/1653 [34:41<26:46,  2.23s/it]
#
# no faces found for 00935.png, copying without faces
# Converting:  57% 934/1653 [34:41<26:42,  2.23s/it]
#
# no faces found for 00936.png, copying without faces
# Converting:  57% 935/1653 [34:41<26:38,  2.23s/it]
#
# no faces found for 00937.png, copying without faces
# Converting:  57% 936/1653 [34:41<26:34,  2.22s/it]
#
# no faces found for 00938.png, copying without faces
# Converting:  57% 937/1653 [34:41<26:30,  2.22s/it]
#
# no faces found for 00939.png, copying without faces
# Converting:  57% 938/1653 [34:41<26:27,  2.22s/it]
#
# no faces found for 00940.png, copying without faces
# Converting:  57% 939/1653 [34:41<26:23,  2.22s/it]
#
# no faces found for 00941.png, copying without faces
# Converting:  57% 940/1653 [34:42<26:19,  2.21s/it]
#
# no faces found for 00942.png, copying without faces
# Converting:  57% 941/1653 [34:42<26:15,  2.21s/it]
#
# no faces found for 00943.png, copying without faces
# Converting:  57% 942/1653 [34:42<26:11,  2.21s/it]
#
# no faces found for 00944.png, copying without faces
# Converting:  57% 943/1653 [34:42<26:07,  2.21s/it]
#
# no faces found for 00945.png, copying without faces
# Converting:  57% 944/1653 [34:42<26:03,  2.21s/it]
#
# no faces found for 00946.png, copying without faces
# Converting:  57% 945/1653 [34:42<25:59,  2.20s/it]
#
# no faces found for 00947.png, copying without faces
# Converting:  57% 946/1653 [34:42<25:56,  2.20s/it]
#
# no faces found for 00948.png, copying without faces
# Converting:  57% 947/1653 [34:42<25:52,  2.20s/it]
#
# no faces found for 00949.png, copying without faces
# Converting:  77% 1279/1653 [53:07<15:31,  2.49s/it]

# %% [markdown]
# # ALL - Train

# %%
import IPython
from google.colab import output

display(IPython.display.Javascript('''
 function ClickConnect(){
   btn = document.querySelector("colab-connect-button")
   if (btn != null){
     console.log("Click colab-connect-button"); 
     btn.click() 
     }
   
   btn = document.getElementById('ok')
   if (btn != null){
     console.log("Click reconnect"); 
     btn.click() 
     }
  }
  
setInterval(ClickConnect,60000)
'''))

print("Done.")

#@title Import from Drive

Mode = "workspace" #@param ["workspace", "data_src", "data_dst", "data_src aligned", "data_dst aligned", "models"]
Archive_name = "workspace.zip" #@param {type:"string"}

#Mount Google Drive as folder
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

def zip_and_copy(path, mode):
  unzip_cmd=" -q "+Archive_name
  
  # %cd $path
  copy_cmd = "/content/drive/My\ Drive/"+Archive_name+" "+path
  # !cp $copy_cmd
  # !unzip $unzip_cmd    
  # !rm $Archive_name

if Mode == "workspace":
  zip_and_copy("/content", "workspace")
elif Mode == "data_src":
  zip_and_copy("/content/workspace", "data_src")
elif Mode == "data_dst":
  zip_and_copy("/content/workspace", "data_dst")
elif Mode == "data_src aligned":
  zip_and_copy("/content/workspace/data_src", "aligned")
elif Mode == "data_dst aligned":
  zip_and_copy("/content/workspace/data_dst", "aligned")
elif Mode == "models":
  zip_and_copy("/content/workspace", "model")
  
print("Done!")

#@title Clone or pull DeepFaceLab from Github

Mode = "clone" #@param ["clone", "pull"]

from pathlib import Path
if (Mode == "clone"):
  # !git clone https://github.com/iperov/DeepFaceLab.git --branch DFL-1.0
else:
  # %cd /content/DeepFaceLab
  # !git pull

# !pip uninstall -y tensorflow
# !pip install -r /content/DeepFaceLab/requirements-colab.txt
# !pip install --upgrade scikit-image
# !apt-get install cuda-10-0

if not Path("/content/pretrain").exists():
  # !wget -q --no-check-certificate -r 'https://github.com/chervonij/DFL-Colab/releases/download/pretrain-CelebA/pretrain_CelebA.zip' -O pretrain_CelebA.zip
  # !mkdir /content/pretrain
  # !unzip -q /content/pretrain_CelebA.zip -d /content/pretrain/
  # !rm /content/pretrain_CelebA.zip

# print("Done!")

#@title Training
Model = "LIAEF128" #@param ["SAEHD", "SAE", "Quick96", "H128", "LIAEF128", "DF", "AVATAR", "DEV_FANSEG"]
Backup_every_hour = True #@param {type:"boolean"}

# %cd "/content"

#Mount Google Drive as folder
from google.colab import drive
drive.mount('/content/drive')

import psutil, os, time

p = psutil.Process(os.getpid())
uptime = time.time() - p.create_time()

if (Backup_every_hour):
  if not os.path.exists('workspace.zip'):
    print("Creating workspace archive ...")
    # !zip -r -q workspace.zip workspace
    print("Archive created!")
  else:
    print("Archive exist!")

if (Backup_every_hour):
  print("Time to end session: "+str(round((43200-uptime)/3600))+" hours")
  backup_time = str(3600)
  backup_cmd = " --execute-program -"+backup_time+" \"import os; os.system('zip -r -q workspace.zip workspace/model'); os.system('cp /content/workspace.zip /content/drive/My\ Drive/'); print('Backed up!') \"" 
elif (round(39600-uptime) > 0):
  print("Time to backup: "+str(round((39600-uptime)/3600))+" hours")
  backup_time = str(round(39600-uptime))
  backup_cmd = " --execute-program "+backup_time+" \"import os; os.system('zip -r -q workspace.zip workspace'); os.system('cp /content/workspace.zip /content/drive/My\ Drive/'); print('Backed up!') \"" 
else:
  print("Session expires in less than an hour.")
  backup_cmd = ""
    
cmd = "DeepFaceLab/main.py train --training-data-src-dir workspace/data_src/aligned --training-data-dst-dir workspace/data_dst/aligned --pretraining-data-dir pretrain --model-dir workspace/model --model "+Model
  
if (backup_cmd != ""):
  train_cmd = (cmd+backup_cmd)
else:
  train_cmd = (cmd)

# !python $train_cmd

# %% [markdown]
# # Welcome to DFL-Colab!
#
# This is an adapted version of the DFL for Google Colab.
# Works only with DFL 1.0
#
# # Overview
# *   Extractor works in full functionality.
# *   Training can work without preview.
# *   Converter works in full functionality.
# *   You can import/export workspace with your Google Drive.
# *   Import/export and another manipulations with workspace you can do in "Manage workspace" block
# *   Google Colab machine active for 12 hours. DFL-Colab makes a backup of your workspace in training mode, after 11 hours from the start of the session.
# *   Google does not like long-term heavy calculations. Therefore, for training more than two sessions in a row, use two Google accounts. It is recommended to split your training over 2 accounts, but you can use one Google Drive account to store your workspace.

# %% [markdown]
# # Check GPU
#
# *   Google Colab can provide you with one of Tesla graphics cards: K80, T4, P4 or P100
# *   Here you can check the model of GPU before using DeepFaceLab

# %%
# !nvidia-smi

# %% [markdown]
# # Clone Github repository and install requirements
#
# * Clone Github repository or pull updates
# * Requirements install is automatically

# %%
#@title Clone or pull DeepFaceLab from Github

Mode = "clone" #@param ["clone", "pull"]

from pathlib import Path
if (Mode == "clone"):
  # !git clone https://github.com/iperov/DeepFaceLab.git --branch DFL-1.0
else:
  # %cd /content/DeepFaceLab
  # !git pull

# !pip uninstall -y tensorflow
# !pip install -r /content/DeepFaceLab/requirements-colab.txt
# !pip install --upgrade scikit-image
# !apt-get install cuda-10-0

if not Path("/content/pretrain").exists():
  # !wget -q --no-check-certificate -r 'https://github.com/chervonij/DFL-Colab/releases/download/pretrain-CelebA/pretrain_CelebA.zip' -O pretrain_CelebA.zip
  # !mkdir /content/pretrain
  # !unzip -q /content/pretrain_CelebA.zip -d /content/pretrain/
  # !rm /content/pretrain_CelebA.zip

print("Done!")

# %% [markdown]
# #Manage workspace
#
#
#
# *   You can import/export workspace or individual data, like model files with Google Drive
# *   Also, you can use HFS (HTTP Fileserver) for directly import/export you workspace from your computer
# *   You can clear all workspace or delete part of it

# %%
#@title Import from Drive

Mode = "workspace" #@param ["workspace", "data_src", "data_dst", "data_src aligned", "data_dst aligned", "models"]
Archive_name = "workspace.zip" #@param {type:"string"}

#Mount Google Drive as folder
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

def zip_and_copy(path, mode):
  unzip_cmd=" -q "+Archive_name
  
  # %cd $path
  copy_cmd = "/content/drive/My\ Drive/"+Archive_name+" "+path
  # !cp $copy_cmd
  # !unzip $unzip_cmd    
  # !rm $Archive_name

if Mode == "workspace":
  zip_and_copy("/content", "workspace")
elif Mode == "data_src":
  zip_and_copy("/content/workspace", "data_src")
elif Mode == "data_dst":
  zip_and_copy("/content/workspace", "data_dst")
elif Mode == "data_src aligned":
  zip_and_copy("/content/workspace/data_src", "aligned")
elif Mode == "data_dst aligned":
  zip_and_copy("/content/workspace/data_dst", "aligned")
elif Mode == "models":
  zip_and_copy("/content/workspace", "model")
  
print("Done!")
# Out:
# Mounted at /content/drive
# /content
# cp: error reading '/content/drive/My Drive/workspace.zip': Input/output error
# [workspace.zip]
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of workspace.zip or
#         workspace.zip.zip, and cannot find workspace.zip.ZIP, period.
# Done!

# %%
#@title Export to Drive { form-width: "30%" }
Mode = "workspace" #@param ["workspace", "data_src", "data_dst", "data_src aligned", "data_dst aligned", "merged", "models", "result video"]
Archive_name = "workspace.zip" #@param {type:"string"}

#Mount Google Drive as folder
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

def zip_and_copy(path, mode):
  zip_cmd="-r -q "+Archive_name+" "
  
  # %cd $path
  zip_cmd+=mode
  # !zip $zip_cmd
  copy_cmd = " "+Archive_name+"  /content/drive/My\ Drive/"
  # !cp $copy_cmd
  # !rm $Archive_name

if Mode == "workspace":
  zip_and_copy("/content", "workspace")
elif Mode == "data_src":
  zip_and_copy("/content/workspace", "data_src")
elif Mode == "data_dst":
  zip_and_copy("/content/workspace", "data_dst")
elif Mode == "data_src aligned":
  zip_and_copy("/content/workspace/data_src", "aligned")
elif Mode == "data_dst aligned":
  zip_and_copy("/content/workspace/data_dst", "aligned")
elif Mode == "merged":
  zip_and_copy("/content/workspace/data_dst", "merged")
elif Mode == "models":
  zip_and_copy("/content/workspace", "model")
elif Mode == "result video":
  # !cp /content/workspace/result.mp4 /content/drive/My\ Drive/
  
print("Done!")

# %%
#@title Import from URL{ form-width: "30%", display-mode: "form" }
URL = "http://" #@param {type:"string"}
Mode = "unzip to content" #@param ["unzip to content", "unzip to content/workspace", "unzip to content/workspace/data_src", "unzip to content/workspace/data_src/aligned", "unzip to content/workspace/data_dst", "unzip to content/workspace/data_dst/aligned", "unzip to content/workspace/model", "download to content/workspace"]

import urllib
from pathlib import Path

def unzip(zip_path, dest_path):

    
  unzip_cmd = " unzip -q " + zip_path + " -d "+dest_path
  # !$unzip_cmd  
  rm_cmd = "rm "+dest_path + url_path.name
  # !$rm_cmd
  print("Unziped!")
  

if Mode == "unzip to content":
  dest_path = "/content/"
elif Mode == "unzip to content/workspace":
  dest_path = "/content/workspace/"
elif Mode == "unzip to content/workspace/data_src":
  dest_path = "/content/workspace/data_src/"
elif Mode == "unzip to content/workspace/data_src/aligned":
  dest_path = "/content/workspace/data_src/aligned/"
elif Mode == "unzip to content/workspace/data_dst":
  dest_path = "/content/workspace/data_dst/"
elif Mode == "unzip to content/workspace/data_dst/aligned":
  dest_path = "/content/workspace/data_dst/aligned/"
elif Mode == "unzip to content/workspace/model":
  dest_path = "/content/workspace/model/"
elif Mode == "download to content/workspace":
  dest_path = "/content/workspace/"

if not Path("/content/workspace").exists():
  cmd = "mkdir /content/workspace; mkdir /content/workspace/data_src; mkdir /content/workspace/data_src/aligned; mkdir /content/workspace/data_dst; mkdir /content/workspace/data_dst/aligned; mkdir /content/workspace/model"
  # !$cmd

url_path = Path(URL)
urllib.request.urlretrieve ( URL, dest_path + url_path.name )

if (url_path.suffix == ".zip") and (Mode!="download to content/workspace"):
  unzip(dest_path + url_path.name, dest_path)

  
print("Done!")

# %%
#@title Export to URL
URL = "http://" #@param {type:"string"}
Mode = "upload workspace" #@param ["upload workspace", "upload data_src", "upload data_dst", "upload data_src aligned", "upload data_dst aligned", "upload merged", "upload model", "upload result video"]

cmd_zip = "zip -r -q "

def run_cmd(zip_path, curl_url):
  cmd_zip = "zip -r -q "+zip_path
  cmd_curl = "curl --silent -F "+curl_url+" -D out.txt > /dev/null"
  # !$cmd_zip
  # !$cmd_curl


if Mode == "upload workspace":
  # %cd "/content"
  run_cmd("workspace.zip workspace/","'data=@/content/workspace.zip' "+URL)
elif Mode == "upload data_src":
  # %cd "/content/workspace"
  run_cmd("data_src.zip data_src/", "'data=@/content/workspace/data_src.zip' "+URL)
elif Mode == "upload data_dst":
  # %cd "/content/workspace"
  run_cmd("data_dst.zip data_dst/", "'data=@/content/workspace/data_dst.zip' "+URL)
elif Mode == "upload data_src aligned":
  # %cd "/content/workspace"
  run_cmd("data_src_aligned.zip data_src/aligned", "'data=@/content/workspace/data_src_aligned.zip' "+URL )
elif Mode == "upload data_dst aligned":
  # %cd "/content/workspace"
  run_cmd("data_dst_aligned.zip data_dst/aligned/", "'data=@/content/workspace/data_dst_aligned.zip' "+URL)
elif Mode == "upload merged":
  # %cd "/content/workspace/data_dst"
  run_cmd("merged.zip merged/","'data=@/content/workspace/data_dst/merged.zip' "+URL )
elif Mode == "upload model":
  # %cd "/content/workspace"
  run_cmd("model.zip model/", "'data=@/content/workspace/model.zip' "+URL)
elif Mode == "upload result video":
  # %cd "/content/workspace"
  run_cmd("result.zip result.mp4", "'data=@/content/workspace/result.zip' "+URL)
  
  
# !rm *.zip

# %cd "/content"
print("Done!")

# %%
#@title Delete and recreate
Mode = "Delete and recreate workspace" #@param ["Delete and recreate workspace", "Delete models", "Delete data_src", "Delete data_src aligned", "Delete data_src video", "Delete data_dst", "Delete data_dst aligned", "Delete merged frames"]

# %cd "/content" 

if Mode == "Delete and recreate workspace":
  cmd = "rm -r /content/workspace ; mkdir /content/workspace; mkdir /content/workspace/data_src; mkdir /content/workspace/data_src/aligned; mkdir /content/workspace/data_dst; mkdir /content/workspace/data_dst/aligned; mkdir /content/workspace/model"  
elif Mode == "Delete models":
  cmd = "rm -r /content/workspace/model/*"
elif Mode == "Delete data_src":
  cmd = "rm /content/workspace/data_src/*.png || rm -r /content/workspace/data_src/*.jpg"
elif Mode == "Delete data_src aligned":
  cmd = "rm -r /content/workspace/data_src/aligned/*"
elif Mode == "Delete data_src video":
  cmd = "rm -r /content/workspace/data_src.*"
elif Mode == "Delete data_dst":
  cmd = "rm /content/workspace/data_dst/*.png || rm /content/workspace/data_dst/*.jpg"
elif Mode == "Delete data_dst aligned":
  cmd = "rm -r /content/workspace/data_dst/aligned/*"
elif Mode == "Delete merged frames":
  cmd = "rm -r /content/workspace/data_dst/merged"
  
# !$cmd
print("Done!")

# %% [markdown]
# # Extract, sorting and faceset tools
# * Extract frames for SRC or DST video.
# * Denoise SRC or DST video. "Factor" param set intesity of denoising
# * Detect and align faces with one of detectors. (S3FD - recommended). If you need, you can get frames with debug landmarks.
# * Options "S3FD (Mark only)" and "S3FD (Extract unaligned)" are needed for the AVATAR model. Before using, read the guide in the DeepFaceLab repository.
# * Export workspace to Google Drive after extract and sort it manually (In "Manage Workspace" block)
# * You can enhance your facesets with DFL FacesetEnhancer. Enhanced images will replace yours in "aligned" directory.

# %%
#@title Extract frames
Video = "data_src" #@param ["data_src", "data_dst"]

# %cd "/content"

cmd = "DeepFaceLab/main.py videoed extract-video"

if Video == "data_dst":
  cmd+= " --input-file workspace/data_dst.* --output-dir workspace/data_dst/"
else:
  cmd+= " --input-file workspace/data_src.* --output-dir workspace/data_src/"
  
# !python $cmd

# %%
#@title Denoise frames
Data = "data_src" #@param ["data_src", "data_dst"]
Factor = 1 #@param {type:"slider", min:1, max:20, step:1}

cmd = "DeepFaceLab/main.py videoed denoise-image-sequence --input-dir workspace/"+Data+" --factor "+str(Factor)

# %cd "/content"
# !python $cmd

# %%
#@title Detect faces
Data = "data_src" #@param ["data_src", "data_dst"]
Detector = "S3FD" #@param ["S3FD", "S3FD (Mark only)", "S3FD (Extract unaligned)", "MT"]
Debug = False #@param {type:"boolean"}

detect_type = "s3fd"
facetype = None

if Detector == "S3FD":
  detect_type = "s3fd"
elif Detector == "S3FD (Mark only)":
  detect_type = "s3fd"
  facetype = "mark_only"
elif Detector == "S3FD (Extract unaligned)":
  detect_type = "s3fd"
  facetype = "full_face_no_align"
elif Detector == "MT":
  detect_type = "mt"

folder = "workspace/"+Data
folder_align = folder+"/aligned"
debug_folder = folder_align+"/debug"

cmd = "DeepFaceLab/main.py extract --input-dir "+folder+" --output-dir "+folder_align

if Debug:
  cmd+= " --debug-dir "+debug_folder

cmd+=" --detector "+detect_type
  
if facetype:
  cmd+=" --face-type "+facetype
  
# %cd "/content"
# !python $cmd

# %%
#@title Sort aligned
Data = "data_src" #@param ["data_src", "data_dst"]
sort_type = "absdiff" #@param ["absdiff","hist", "hist-dissim", "face-yaw", "face-pitch", "vggface", "blur", "final", "final-no-blur"]

cmd = "DeepFaceLab/main.py sort --input-dir workspace/"+Data+"/aligned --by "+sort_type

# %cd "/content"
# !python $cmd

# %%
#@title Faceset Enhancer
Data = "data_src" #@param ["data_src", "data_dst"]

data_path = "/content/workspace/"+Data+"/aligned"

cmd = "/content/DeepFaceLab/main.py facesettool enhance --input-dir "+data_path
# !python $cmd

# %% [markdown]
# # Train model
#
# * Choose your model type, but SAEHD is recommend for everyone
# * Set model options on output field
# * You can see preview manually, if go to model folder in filemanager and double click on preview.jpg file
# * Your workspace will be archived and upload to mounted Drive after 11 hours from start session
# * If you select "Backup_every_hour" option, your workspace will be backed up every hour.
# * Also, you can export your workspace manually in "Manage workspace" block

# %%
#@title Training
Model = "SAEHD" #@param ["SAEHD", "SAE", "Quick96", "H128", "LIAEF128", "DF", "AVATAR", "DEV_FANSEG"]
Backup_every_hour = True #@param {type:"boolean"}

# %cd "/content"

#Mount Google Drive as folder
from google.colab import drive
drive.mount('/content/drive')

import psutil, os, time

p = psutil.Process(os.getpid())
uptime = time.time() - p.create_time()

if (Backup_every_hour):
  if not os.path.exists('workspace.zip'):
    print("Creating workspace archive ...")
    # !zip -r -q workspace.zip workspace
    print("Archive created!")
  else:
    print("Archive exist!")

if (Backup_every_hour):
  print("Time to end session: "+str(round((43200-uptime)/3600))+" hours")
  backup_time = str(3600)
  backup_cmd = " --execute-program -"+backup_time+" \"import os; os.system('zip -r -q workspace.zip workspace/model'); os.system('cp /content/workspace.zip /content/drive/My\ Drive/'); print('Backed up!') \"" 
elif (round(39600-uptime) > 0):
  print("Time to backup: "+str(round((39600-uptime)/3600))+" hours")
  backup_time = str(round(39600-uptime))
  backup_cmd = " --execute-program "+backup_time+" \"import os; os.system('zip -r -q workspace.zip workspace'); os.system('cp /content/workspace.zip /content/drive/My\ Drive/'); print('Backed up!') \"" 
else:
  print("Session expires in less than an hour.")
  backup_cmd = ""
    
cmd = "DeepFaceLab/main.py train --training-data-src-dir workspace/data_src/aligned --training-data-dst-dir workspace/data_dst/aligned --pretraining-data-dir pretrain --model-dir workspace/model --model "+Model
  
if (backup_cmd != ""):
  train_cmd = (cmd+backup_cmd)
else:
  train_cmd = (cmd)

# !python $train_cmd

# %% [markdown]
# # Convert frames

# %%
#@title Convert
Model = "SAEHD" #@param ["SAEHD", "SAE", "Quick96", "H128", "LIAEF128", "DF", "AVATAR" ]

if Model == "AVATAR":  
  cmd = "DeepFaceLab/main.py convert --input-dir workspace/data_dst/aligned --output-dir workspace/data_dst/merged --model-dir workspace/model --model "+Model
else:
  cmd = "DeepFaceLab/main.py convert --input-dir workspace/data_dst --output-dir workspace/data_dst/merged --aligned-dir workspace/data_dst/aligned --model-dir workspace/model --model "+Model

# %cd "/content"
# !python $cmd

# %%
#@title Get result video and copy to Drive 

# !python DeepFaceLab/main.py videoed video-from-sequence --input-dir workspace/data_dst/merged --output-file workspace/result.mp4 --reference-file workspace/data_dst.mp4
# !cp /content/workspace/result.mp4 /content/drive/My\ Drive/

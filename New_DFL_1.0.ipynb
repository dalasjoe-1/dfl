# %% [markdown]
# <a href="https://colab.research.google.com/github/dalasjoe-1/dfl/blob/master/New_DFL_1.0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Prevent random disconnects

Prevent Disconnet = "OK" #@param {type:"string"}

import IPython
from google.colab import output

display(IPython.display.Javascript('''
  function ClickConnect(){
    console.log("Working"); 
    document.querySelector("colab-connect-button").click() 
  }
  var connect_timer = setInterval(ClickConnect,60000)
'''))

print("Done.")

# %%
#@title Import from Drive, Clone githib, Train model

import IPython
from google.colab import output

display(IPython.display.Javascript('''
  function ClickConnect(){
    console.log("Working"); 
    document.querySelector("colab-connect-button").click() 
  }
  var connect_timer = setInterval(ClickConnect,60000)
'''))

print("Done.")



Mode = "workspace" #@param ["workspace", "data_src", "data_dst", "data_src aligned", "data_dst aligned", "models"]
Archive_name = "workspace.zip" #@param {type:"string"}

#Mount Google Drive as folder
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

def zip_and_copy(path, mode):
  unzip_cmd=" -q "+Archive_name
  
  # %cd $path
  copy_cmd = "/content/drive/My\ Drive/"+Archive_name+" "+path
  # !cp $copy_cmd
  # !unzip $unzip_cmd    
  # !rm $Archive_name

if Mode == "workspace":
  zip_and_copy("/content", "workspace")
elif Mode == "data_src":
  zip_and_copy("/content/workspace", "data_src")
elif Mode == "data_dst":
  zip_and_copy("/content/workspace", "data_dst")
elif Mode == "data_src aligned":
  zip_and_copy("/content/workspace/data_src", "aligned")
elif Mode == "data_dst aligned":
  zip_and_copy("/content/workspace/data_dst", "aligned")
elif Mode == "models":
  zip_and_copy("/content/workspace", "model")
  
print("Import Done!")

#@title Clone or pull DeepFaceLab from Github

Mode = "clone" #@param ["clone", "pull"]

from pathlib import Path
if (Mode == "clone"):
  # !git clone https://github.com/iperov/DeepFaceLab.git --branch DFL-1.0
else:
  # %cd /content/DeepFaceLab
  # !git pull

# !pip install -r /content/DeepFaceLab/requirements-colab.txt
# !pip install --upgrade scikit-image
# !apt-get install cuda-10-0

if not Path("/content/workspace").exists():
  # !wget -q --no-check-certificate -r 'https://docs.google.com/uc?export=download&id=1hTH2h6l_4kKrczA8EkN6GyuXx4lzmCnK' -O pretrain_CelebA.zip
  # !mkdir /content/pretrain
  # !unzip -q /content/pretrain_CelebA.zip -d /content/pretrain/
  # !rm /content/pretrain_CelebA.zip

print("Clone Done!")

#@title Training
Model = "LIAEF128" #@param ["SAEHD", "SAE", "Quick96", "H128", "LIAEF128", "DF", "AVATAR", "DEV_FANSEG"]
Backup_every_hour = True #@param {type:"boolean"}


# %cd "/content"

#Mount Google Drive as folder
from google.colab import drive
drive.mount('/content/drive')

import psutil, os, time

p = psutil.Process(os.getpid())
uptime = time.time() - p.create_time()

if (Backup_every_hour):
  if not os.path.exists('workspace.zip'):
    print("Creating workspace archive ...")
    # !zip -r -q workspace.zip workspace
    print("Archive created!")
  else:
    print("Archive exist!")

if (Backup_every_hour):
  print("Time to end session: "+str(round((43200-uptime)/3600))+" hours")
  backup_time = str(3600)
  backup_cmd = " --execute-program -"+backup_time+" \"import os; os.system('zip -r -q workspace.zip workspace/model'); os.system('cp /content/workspace.zip /content/drive/My\ Drive/'); print('Backed up!') \"" 
elif (round(39600-uptime) > 0):
  print("Time to backup: "+str(round((39600-uptime)/3600))+" hours")
  backup_time = str(round(39600-uptime))
  backup_cmd = " --execute-program "+backup_time+" \"import os; os.system('zip -r -q workspace.zip workspace'); os.system('cp /content/workspace.zip /content/drive/My\ Drive/'); print('Backed up!') \"" 
else:
  print("Session expires in less than an hour.")
  backup_cmd = ""
    
cmd = "DeepFaceLab/main.py train --training-data-src-dir workspace/data_src/aligned --training-data-dst-dir workspace/data_dst/aligned --pretraining-data-dir pretrain/aligned --model-dir workspace/model --model "+Model
  
if (backup_cmd != ""):
  train_cmd = (cmd+backup_cmd)
else:
  train_cmd = (cmd)

# !python $train_cmd

# %%
#@title Export to Drive { form-width: "30%" }
Mode = "workspace" #@param ["workspace", "data_src", "data_dst", "data_src aligned", "data_dst aligned", "merged", "models", "result video"]
Archive_name = "workspace.zip" #@param {type:"string"}

#Mount Google Drive as folder
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

def zip_and_copy(path, mode):
  zip_cmd="-r -q "+Archive_name+" "
  
  # %cd $path
  zip_cmd+=mode
  # !zip $zip_cmd
  copy_cmd = " "+Archive_name+"  /content/drive/My\ Drive/"
  # !cp $copy_cmd
  # !rm $Archive_name

if Mode == "workspace":
  zip_and_copy("/content", "workspace")
elif Mode == "data_src":
  zip_and_copy("/content/workspace", "data_src")
elif Mode == "data_dst":
  zip_and_copy("/content/workspace", "data_dst")
elif Mode == "data_src aligned":
  zip_and_copy("/content/workspace/data_src", "aligned")
elif Mode == "data_dst aligned":
  zip_and_copy("/content/workspace/data_dst", "aligned")
elif Mode == "merged":
  zip_and_copy("/content/workspace/data_dst", "merged")
elif Mode == "models":
  zip_and_copy("/content/workspace", "model")
elif Mode == "result video":
  # !cp /content/workspace/result.mp4 /content/drive/My\ Drive/
  
print("Done!")

# %%
#@title Training
Model = "SAEHD" #@param ["SAEHD", "SAE", "Quick96", "H128", "LIAEF128", "DF", "AVATAR", "DEV_FANSEG"]
Backup_every_hour = True #@param {type:"boolean"}

# %cd "/content"

#Mount Google Drive as folder
from google.colab import drive
drive.mount('/content/drive')

import psutil, os, time

p = psutil.Process(os.getpid())
uptime = time.time() - p.create_time()

if (Backup_every_hour):
  if not os.path.exists('workspace.zip'):
    print("Creating workspace archive ...")
    # !zip -r -q workspace.zip workspace
    print("Archive created!")
  else:
    print("Archive exist!")

if (Backup_every_hour):
  print("Time to end session: "+str(round((43200-uptime)/3600))+" hours")
  backup_time = str(3600)
  backup_cmd = " --execute-program -"+backup_time+" \"import os; os.system('zip -r -q workspace.zip workspace/model'); os.system('cp /content/workspace.zip /content/drive/My\ Drive/'); print('Backed up!') \"" 
elif (round(39600-uptime) > 0):
  print("Time to backup: "+str(round((39600-uptime)/3600))+" hours")
  backup_time = str(round(39600-uptime))
  backup_cmd = " --execute-program "+backup_time+" \"import os; os.system('zip -r -q workspace.zip workspace'); os.system('cp /content/workspace.zip /content/drive/My\ Drive/'); print('Backed up!') \"" 
else:
  print("Session expires in less than an hour.")
  backup_cmd = ""
    
cmd = "DeepFaceLab/main.py train --training-data-src-dir workspace/data_src/aligned --training-data-dst-dir workspace/data_dst/aligned --pretraining-data-dir pretrain/aligned --model-dir workspace/model --model "+Model
  
if (backup_cmd != ""):
  train_cmd = (cmd+backup_cmd)
else:
  train_cmd = (cmd)

# !python $train_cmd

# %%
#@title Import, Extract and Convert and Save MP4


Mode = "workspace" #@param ["workspace", "data_src", "data_dst", "data_src aligned", "data_dst aligned", "models"]
Archive_name = "workspace.zip" #@param {type:"string"}

#Mount Google Drive as folder
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

def zip_and_copy(path, mode):
  unzip_cmd=" -q "+Archive_name
  
  # %cd $path
  copy_cmd = "/content/drive/My\ Drive/"+Archive_name+" "+path
  # !cp $copy_cmd
  # !unzip $unzip_cmd    
  # !rm $Archive_name

if Mode == "workspace":
  zip_and_copy("/content", "workspace")
elif Mode == "data_src":
  zip_and_copy("/content/workspace", "data_src")
elif Mode == "data_dst":
  zip_and_copy("/content/workspace", "data_dst")
elif Mode == "data_src aligned":
  zip_and_copy("/content/workspace/data_src", "aligned")
elif Mode == "data_dst aligned":
  zip_and_copy("/content/workspace/data_dst", "aligned")
elif Mode == "models":
  zip_and_copy("/content/workspace", "model")
  
print("Done!")

#@title Extract frames
Video = "data_dst" #@param ["data_src", "data_dst"]

# %cd "/content"

cmd = "DeepFaceLab/main.py videoed extract-video --fps 0 --output-ext png"

if Video == "data_dst":
  cmd+= " --input-file workspace/data_dst.* --output-dir workspace/data_dst/"
else:
  cmd+= " --input-file workspace/data_src.* --output-dir workspace/data_src/"
  
# !python $cmd


Model = "LIAEF128" #@param ["SAEHD", "SAE", "Quick96", "H128", "LIAEF128", "DF", "AVATAR" ]

if Model == "AVATAR":  
  cmd = "DeepFaceLab/main.py convert --input-dir workspace/data_dst/aligned --output-dir workspace/data_dst/merged --model-dir workspace/model --model "+Model
else:
  cmd = "DeepFaceLab/main.py convert --input-dir workspace/data_dst --output-dir workspace/data_dst/merged --aligned-dir workspace/data_dst/aligned --model-dir workspace/model --model "+Model

# %cd "/content"
# !python $cmd

#@title Get result video and copy to Drive 

FileName = 'eun_beau2_DF_seamless_15_250' #@param {type:"string"}

path1 = "DeepFaceLab/main.py videoed video-from-sequence --input-dir workspace/data_dst/merged --output-file workspace/" + FileName + " --reference-file workspace/data_dst.mp4 --bitrate 16"
path2 = "/content/workspace/" + FileName  + " /content/drive/My\ Drive/"

# !python $path1
# !cp $path2
# Out:
# Converting:  36% 1467/4112 [13:58<25:12,  1.75it/s]

# %%
#@title Convert and Save MP4
Model = "LIAEF128" #@param ["SAEHD", "SAE", "Quick96", "H128", "LIAEF128", "DF", "AVATAR" ]

if Model == "AVATAR":  
  cmd = "DeepFaceLab/main.py convert --input-dir workspace/data_dst/aligned --output-dir workspace/data_dst/merged --model-dir workspace/model --model "+Model
else:
  cmd = "DeepFaceLab/main.py convert --input-dir workspace/data_dst --output-dir workspace/data_dst/merged --aligned-dir workspace/data_dst/aligned --model-dir workspace/model --model "+Model

# %cd "/content"
# !python $cmd

#@title Get result video and copy to Drive 

FileName = 'eun_beau2_DF_seamless_15_250' #@param {type:"string"}

path1 = "DeepFaceLab/main.py videoed video-from-sequence --input-dir workspace/data_dst/merged --output-file workspace/" + FileName + " --reference-file workspace/data_dst.mp4 --bitrate 16"
path2 = "/content/workspace/" + FileName  + " /content/drive/My\ Drive/"

# !python $path1
# !cp $path2
# Out:
# Converting:  79% 3265/4112 [29:20<07:36,  1.85it/s]
#
# no faces found for 03267.png, copying without faces
# Converting:  79% 3268/4112 [29:22<07:35,  1.85it/s]
#
# no faces found for 03270.png, copying without faces
# Converting:  80% 3270/4112 [29:22<07:33,  1.86it/s]
#
# no faces found for 03271.png, copying without faces
#
#
# no faces found for 03272.png, copying without faces
# Converting:  80% 3272/4112 [29:22<07:32,  1.86it/s]
#
# no faces found for 03273.png, copying without faces
#
#
# no faces found for 03274.png, copying without faces
# Converting:  80% 3274/4112 [29:22<07:31,  1.86it/s]
#
# no faces found for 03275.png, copying without faces
#
#
# no faces found for 03276.png, copying without faces
# Converting:  80% 3275/4112 [29:22<07:30,  1.86it/s]
#
# no faces found for 03277.png, copying without faces
# Converting:  80% 3276/4112 [29:22<07:29,  1.86it/s]
#
# no faces found for 03278.png, copying without faces
# Converting:  80% 3277/4112 [29:22<07:29,  1.86it/s]
#
# no faces found for 03279.png, copying without faces
# Converting:  80% 3278/4112 [29:22<07:28,  1.86it/s]
#
# no faces found for 03280.png, copying without faces
# Converting:  80% 3280/4112 [29:23<07:27,  1.86it/s]
#
# no faces found for 03281.png, copying without faces
#
#
# no faces found for 03282.png, copying without faces
# Converting:  80% 3282/4112 [29:23<07:25,  1.86it/s]
#
# no faces found for 03283.png, copying without faces
#
#
# no faces found for 03284.png, copying without faces
# Converting:  80% 3283/4112 [29:23<07:25,  1.86it/s]
#
# no faces found for 03285.png, copying without faces
# Converting:  80% 3284/4112 [29:23<07:24,  1.86it/s]
#
# no faces found for 03286.png, copying without faces
# Converting:  80% 3285/4112 [29:23<07:23,  1.86it/s]
#
# no faces found for 03287.png, copying without faces
# Converting:  80% 3286/4112 [29:23<07:23,  1.86it/s]
#
# no faces found for 03288.png, copying without faces
# Converting:  80% 3287/4112 [29:23<07:22,  1.86it/s]
#
# no faces found for 03289.png, copying without faces
# Converting:  80% 3288/4112 [29:23<07:21,  1.86it/s]
#
# no faces found for 03290.png, copying without faces
# Converting:  80% 3290/4112 [29:23<07:20,  1.87it/s]
#
# no faces found for 03291.png, copying without faces
#
#
# no faces found for 03292.png, copying without faces
# Converting:  80% 3292/4112 [29:23<07:19,  1.87it/s]
#
# no faces found for 03293.png, copying without faces
#
#
# no faces found for 03294.png, copying without faces
# Converting:  80% 3294/4112 [29:23<07:17,  1.87it/s]
#
# no faces found for 03295.png, copying without faces
#
#
# no faces found for 03296.png, copying without faces
# Converting:  80% 3296/4112 [29:23<07:16,  1.87it/s]
#
# no faces found for 03297.png, copying without faces
#
#
# no faces found for 03298.png, copying without faces
# Converting:  87% 3596/4112 [32:32<04:40,  1.84it/s]
#
# no faces found for 03598.png, copying without faces
# Converting:  88% 3608/4112 [32:39<04:33,  1.84it/s]
#
# no faces found for 03609.png, copying without faces
# Converting:  88% 3637/4112 [32:55<04:18,  1.84it/s]
#
# no faces found for 03639.png, copying without faces
# Converting:  88% 3639/4112 [32:56<04:16,  1.84it/s]
#
# no faces found for 03640.png, copying without faces
#
#
# no faces found for 03641.png, copying without faces
# Converting:  89% 3641/4112 [32:56<04:15,  1.84it/s]
#
# no faces found for 03642.png, copying without faces
#
#
# no faces found for 03643.png, copying without faces
# Converting:  89% 3643/4112 [32:56<04:14,  1.84it/s]
#
# no faces found for 03644.png, copying without faces
#
#
# no faces found for 03645.png, copying without faces
# Converting:  89% 3645/4112 [32:56<04:13,  1.84it/s]
#
# no faces found for 03646.png, copying without faces
#
#
# no faces found for 03647.png, copying without faces
# Converting:  89% 3646/4112 [32:56<04:12,  1.84it/s]
#
# no faces found for 03648.png, copying without faces
# Converting:  89% 3647/4112 [32:56<04:12,  1.85it/s]
#
# no faces found for 03649.png, copying without faces
# Converting:  89% 3648/4112 [32:56<04:11,  1.85it/s]
#
# no faces found for 03650.png, copying without faces
# Converting:  89% 3649/4112 [32:56<04:10,  1.85it/s]
#
# no faces found for 03651.png, copying without faces
# Converting:  89% 3650/4112 [32:56<04:10,  1.85it/s]
#
# no faces found for 03652.png, copying without faces
# Converting:  89% 3651/4112 [32:56<04:09,  1.85it/s]
#
# no faces found for 03653.png, copying without faces
# Converting:  89% 3653/4112 [32:56<04:08,  1.85it/s]
#
# no faces found for 03654.png, copying without faces
#
#
# no faces found for 03655.png, copying without faces
# Converting:  89% 3655/4112 [32:56<04:07,  1.85it/s]
#
# no faces found for 03656.png, copying without faces
#
#
# no faces found for 03657.png, copying without faces
# Converting:  89% 3656/4112 [32:57<04:06,  1.85it/s]
#
# no faces found for 03658.png, copying without faces
# Converting:  89% 3657/4112 [32:57<04:05,  1.85it/s]
#
# no faces found for 03659.png, copying without faces
# Converting:  89% 3658/4112 [32:57<04:05,  1.85it/s]
#
# no faces found for 03660.png, copying without faces
# Converting:  89% 3659/4112 [32:57<04:04,  1.85it/s]
#
# no faces found for 03661.png, copying without faces
# Converting:  89% 3660/4112 [32:57<04:04,  1.85it/s]
#
# no faces found for 03662.png, copying without faces
# Converting:  89% 3661/4112 [32:57<04:03,  1.85it/s]
#
# no faces found for 03663.png, copying without faces
# Converting:  89% 3663/4112 [32:57<04:02,  1.85it/s]
#
# no faces found for 03664.png, copying without faces
#
#
# no faces found for 03665.png, copying without faces
# Converting:  89% 3665/4112 [32:57<04:01,  1.85it/s]
#
# no faces found for 03666.png, copying without faces
#
#
# no faces found for 03667.png, copying without faces
# Converting:  89% 3667/4112 [32:57<03:59,  1.85it/s]
#
# no faces found for 03668.png, copying without faces
#
#
# no faces found for 03669.png, copying without faces
# Converting:  89% 3669/4112 [32:57<03:58,  1.86it/s]
#
# no faces found for 03670.png, copying without faces
#
#
# no faces found for 03671.png, copying without faces
# Converting:  89% 3671/4112 [32:57<03:57,  1.86it/s]
#
# no faces found for 03672.png, copying without faces
#
#
# no faces found for 03673.png, copying without faces
# Converting:  89% 3673/4112 [32:57<03:56,  1.86it/s]
#
# no faces found for 03674.png, copying without faces
#
#
# no faces found for 03675.png, copying without faces
# Converting:  89% 3675/4112 [32:57<03:55,  1.86it/s]
#
# no faces found for 03676.png, copying without faces
#
#
# no faces found for 03677.png, copying without faces
# Converting:  89% 3677/4112 [32:57<03:54,  1.86it/s]
#
# no faces found for 03678.png, copying without faces
#
#
# no faces found for 03679.png, copying without faces
# Converting:  89% 3679/4112 [32:58<03:52,  1.86it/s]
#
# no faces found for 03680.png, copying without faces
#
#
# no faces found for 03681.png, copying without faces
# Converting:  90% 3681/4112 [32:58<03:51,  1.86it/s]
#
# no faces found for 03682.png, copying without faces
#
#
# no faces found for 03683.png, copying without faces
# Converting:  90% 3683/4112 [32:58<03:50,  1.86it/s]
#
# no faces found for 03684.png, copying without faces
#
#
# no faces found for 03685.png, copying without faces
# Converting:  90% 3685/4112 [32:58<03:49,  1.86it/s]
#
# no faces found for 03686.png, copying without faces
#
#
# no faces found for 03687.png, copying without faces
# Converting:  90% 3687/4112 [32:58<03:48,  1.86it/s]
#
# no faces found for 03688.png, copying without faces
#
#
# no faces found for 03689.png, copying without faces
# Converting:  90% 3688/4112 [32:58<03:47,  1.86it/s]
#
# no faces found for 03690.png, copying without faces
# Converting:  90% 3689/4112 [32:58<03:46,  1.86it/s]
#
# no faces found for 03691.png, copying without faces
# Converting:  90% 3690/4112 [32:58<03:46,  1.87it/s]
#
# no faces found for 03692.png, copying without faces
# Converting:  90% 3692/4112 [32:58<03:45,  1.87it/s]
#
# no faces found for 03693.png, copying without faces
#
#
# no faces found for 03694.png, copying without faces
# Converting:  90% 3693/4112 [32:58<03:44,  1.87it/s]
#
# no faces found for 03695.png, copying without faces
# Converting:  90% 3694/4112 [32:58<03:43,  1.87it/s]
#
# no faces found for 03696.png, copying without faces
# Converting:  90% 3695/4112 [32:58<03:43,  1.87it/s]
#
# no faces found for 03697.png, copying without faces
# Converting:  90% 3696/4112 [32:58<03:42,  1.87it/s]
#
# no faces found for 03698.png, copying without faces
# Converting:  90% 3697/4112 [32:58<03:42,  1.87it/s]
#
# no faces found for 03699.png, copying without faces
# Converting:  90% 3698/4112 [32:58<03:41,  1.87it/s]
#
# no faces found for 03700.png, copying without faces
# Converting:  90% 3699/4112 [32:58<03:40,  1.87it/s]
#
# no faces found for 03701.png, copying without faces
# Converting:  90% 3700/4112 [32:58<03:40,  1.87it/s]
#
# no faces found for 03702.png, copying without faces
# Converting:  90% 3701/4112 [32:58<03:39,  1.87it/s]
#
# no faces found for 03703.png, copying without faces
# Converting:  90% 3703/4112 [32:59<03:38,  1.87it/s]
#
# no faces found for 03704.png, copying without faces
#
#
# no faces found for 03705.png, copying without faces
# Converting:  90% 3705/4112 [32:59<03:37,  1.87it/s]
#
# no faces found for 03706.png, copying without faces
#
#
# no faces found for 03707.png, copying without faces
# Converting:  97% 3979/4112 [35:43<01:11,  1.86it/s]
#
# no faces found for 03981.png, copying without faces
# Converting:  97% 3981/4112 [35:43<01:10,  1.86it/s]
#
# no faces found for 03982.png, copying without faces
#
#
# no faces found for 03983.png, copying without faces
# Converting:  97% 3982/4112 [35:43<01:09,  1.86it/s]
#
# no faces found for 03984.png, copying without faces
# Converting:  97% 3983/4112 [35:43<01:09,  1.86it/s]
#
# no faces found for 03985.png, copying without faces
# Converting:  97% 3984/4112 [35:43<01:08,  1.86it/s]
#
# no faces found for 03986.png, copying without faces
# Converting:  97% 3986/4112 [35:43<01:07,  1.86it/s]
#
# no faces found for 03987.png, copying without faces
#
#
# no faces found for 03988.png, copying without faces
# Converting:  97% 3988/4112 [35:43<01:06,  1.86it/s]
#
# no faces found for 03989.png, copying without faces
#
#
# no faces found for 03990.png, copying without faces
# Converting:  97% 3990/4112 [35:44<01:05,  1.86it/s]
#
# no faces found for 03991.png, copying without faces
#
#
# no faces found for 03992.png, copying without faces
# Converting:  97% 3992/4112 [35:44<01:04,  1.86it/s]
#
# no faces found for 03993.png, copying without faces
#
#
# no faces found for 03994.png, copying without faces
# Converting:  97% 3993/4112 [35:44<01:03,  1.86it/s]
#
# no faces found for 03995.png, copying without faces
# Converting:  97% 3995/4112 [35:44<01:02,  1.86it/s]
#
# no faces found for 03996.png, copying without faces
#
#
# no faces found for 03997.png, copying without faces
# Converting:  97% 3997/4112 [35:44<01:01,  1.86it/s]
#
# no faces found for 03998.png, copying without faces
#
#
# no faces found for 03999.png, copying without faces
# Converting:  97% 3998/4112 [35:44<01:01,  1.86it/s]
#
# no faces found for 04000.png, copying without faces
# Converting:  97% 3999/4112 [35:44<01:00,  1.86it/s]
#
# no faces found for 04001.png, copying without faces
# Converting:  97% 4000/4112 [35:44<01:00,  1.87it/s]
#
# no faces found for 04002.png, copying without faces
# Converting:  97% 4002/4112 [35:44<00:58,  1.87it/s]
#
# no faces found for 04003.png, copying without faces
#
#
# no faces found for 04004.png, copying without faces
# Converting:  97% 4004/4112 [35:44<00:57,  1.87it/s]
#
# no faces found for 04005.png, copying without faces
#
#
# no faces found for 04006.png, copying without faces
# Converting:  97% 4005/4112 [35:44<00:57,  1.87it/s]
#
# no faces found for 04007.png, copying without faces
# Converting:  97% 4007/4112 [35:45<00:56,  1.87it/s]
#
# no faces found for 04008.png, copying without faces
#
#
# no faces found for 04009.png, copying without faces
# Converting:  97% 4009/4112 [35:45<00:55,  1.87it/s]
#
# no faces found for 04010.png, copying without faces
#
#
# no faces found for 04011.png, copying without faces
# Converting:  98% 4010/4112 [35:45<00:54,  1.87it/s]
#
# no faces found for 04012.png, copying without faces
# Converting:  98% 4012/4112 [35:45<00:53,  1.87it/s]
#
# no faces found for 04013.png, copying without faces
#
#
# no faces found for 04014.png, copying without faces
# Converting:  98% 4014/4112 [35:45<00:52,  1.87it/s]
#
# no faces found for 04015.png, copying without faces
#
#
# no faces found for 04016.png, copying without faces
# Converting:  98% 4016/4112 [35:45<00:51,  1.87it/s]
#
# no faces found for 04017.png, copying without faces
#
#
# no faces found for 04018.png, copying without faces
# Converting:  98% 4017/4112 [35:45<00:50,  1.87it/s]
#
# no faces found for 04019.png, copying without faces
# Converting:  98% 4018/4112 [35:45<00:50,  1.87it/s]
#
# no faces found for 04020.png, copying without faces
# Converting:  98% 4019/4112 [35:45<00:49,  1.87it/s]
#
# no faces found for 04021.png, copying without faces
# Converting:  98% 4020/4112 [35:45<00:49,  1.87it/s]
#
# no faces found for 04022.png, copying without faces
# Converting:  98% 4021/4112 [35:45<00:48,  1.87it/s]
#
# no faces found for 04023.png, copying without faces
# Converting:  98% 4022/4112 [35:45<00:48,  1.87it/s]
#
# no faces found for 04024.png, copying without faces
# Converting:  98% 4023/4112 [35:45<00:47,  1.87it/s]
#
# no faces found for 04025.png, copying without faces
# Converting:  98% 4024/4112 [35:46<00:46,  1.88it/s]
#
# no faces found for 04026.png, copying without faces
# Converting:  98% 4026/4112 [35:46<00:45,  1.88it/s]
#
# no faces found for 04027.png, copying without faces
#
#
# no faces found for 04028.png, copying without faces
# Converting:  98% 4028/4112 [35:46<00:44,  1.88it/s]
#
# no faces found for 04029.png, copying without faces
#
#
# no faces found for 04030.png, copying without faces
# Converting:  98% 4030/4112 [35:46<00:43,  1.88it/s]
#
# no faces found for 04031.png, copying without faces
#
#
# no faces found for 04032.png, copying without faces
# Converting:  98% 4032/4112 [35:46<00:42,  1.88it/s]
#
# no faces found for 04033.png, copying without faces
#
#
# no faces found for 04034.png, copying without faces
# Converting:  98% 4034/4112 [35:46<00:41,  1.88it/s]
#
# no faces found for 04035.png, copying without faces
#
#
# no faces found for 04036.png, copying without faces
# Converting:  98% 4036/4112 [35:46<00:40,  1.88it/s]
#
# no faces found for 04037.png, copying without faces
#
#
# no faces found for 04038.png, copying without faces
# Converting:  98% 4038/4112 [35:46<00:39,  1.88it/s]
#
# no faces found for 04039.png, copying without faces
#
#
# no faces found for 04040.png, copying without faces
# Converting:  98% 4040/4112 [35:46<00:38,  1.88it/s]
#
# no faces found for 04041.png, copying without faces
#
#
# no faces found for 04042.png, copying without faces
# Converting:  98% 4042/4112 [35:46<00:37,  1.88it/s]
#
# no faces found for 04043.png, copying without faces
#
#
# no faces found for 04044.png, copying without faces
# Converting:  98% 4044/4112 [35:46<00:36,  1.88it/s]
#
# no faces found for 04045.png, copying without faces
#
#
# no faces found for 04046.png, copying without faces
# Converting:  98% 4045/4112 [35:46<00:35,  1.88it/s]
#
# no faces found for 04047.png, copying without faces
# Converting:  98% 4046/4112 [35:46<00:35,  1.88it/s]
#
# no faces found for 04048.png, copying without faces
# Converting:  98% 4047/4112 [35:47<00:34,  1.88it/s]
#
# no faces found for 04049.png, copying without faces
# Converting:  98% 4049/4112 [35:47<00:33,  1.89it/s]
#
# no faces found for 04050.png, copying without faces
#
#
# no faces found for 04051.png, copying without faces
# Converting:  98% 4050/4112 [35:47<00:32,  1.89it/s]
#
# no faces found for 04052.png, copying without faces
# Converting:  99% 4052/4112 [35:47<00:31,  1.89it/s]
#
# no faces found for 04053.png, copying without faces
#
#
# no faces found for 04054.png, copying without faces
# Converting:  99% 4054/4112 [35:47<00:30,  1.89it/s]
#
# no faces found for 04055.png, copying without faces
#
#
# no faces found for 04056.png, copying without faces
# Converting:  99% 4056/4112 [35:47<00:29,  1.89it/s]
#
# no faces found for 04057.png, copying without faces
#
#
# no faces found for 04058.png, copying without faces
# Converting:  99% 4058/4112 [35:47<00:28,  1.89it/s]
#
# no faces found for 04059.png, copying without faces
#
#
# no faces found for 04060.png, copying without faces
# Converting:  99% 4060/4112 [35:47<00:27,  1.89it/s]
#
# no faces found for 04061.png, copying without faces
#
#
# no faces found for 04062.png, copying without faces
# Converting:  99% 4061/4112 [35:47<00:26,  1.89it/s]
#
# no faces found for 04063.png, copying without faces
# Converting:  99% 4062/4112 [35:47<00:26,  1.89it/s]
#
# no faces found for 04064.png, copying without faces
# Converting:  99% 4063/4112 [35:47<00:25,  1.89it/s]
#
# no faces found for 04065.png, copying without faces
# Converting:  99% 4064/4112 [35:47<00:25,  1.89it/s]
#
# no faces found for 04066.png, copying without faces
# Converting:  99% 4065/4112 [35:47<00:24,  1.89it/s]
#
# no faces found for 04067.png, copying without faces
# Converting:  99% 4066/4112 [35:47<00:24,  1.89it/s]
#
# no faces found for 04068.png, copying without faces
# Converting:  99% 4068/4112 [35:47<00:23,  1.89it/s]
#
# no faces found for 04069.png, copying without faces
#
#
# no faces found for 04070.png, copying without faces
# Converting:  99% 4069/4112 [35:47<00:22,  1.89it/s]
#
# no faces found for 04071.png, copying without faces
# Converting:  99% 4070/4112 [35:47<00:22,  1.89it/s]
#
# no faces found for 04072.png, copying without faces
# Converting:  99% 4071/4112 [35:48<00:21,  1.90it/s]
#
# no faces found for 04073.png, copying without faces
# Converting:  99% 4072/4112 [35:48<00:21,  1.90it/s]
#
# no faces found for 04074.png, copying without faces
# Converting:  99% 4073/4112 [35:48<00:20,  1.90it/s]
#
# no faces found for 04075.png, copying without faces
# Converting:  99% 4074/4112 [35:48<00:20,  1.90it/s]
#
# no faces found for 04076.png, copying without faces
# Converting:  99% 4076/4112 [35:48<00:18,  1.90it/s]
#
# no faces found for 04077.png, copying without faces
#
#
# no faces found for 04078.png, copying without faces
# Converting:  99% 4078/4112 [35:48<00:17,  1.90it/s]
#
# no faces found for 04079.png, copying without faces
#
#
# no faces found for 04080.png, copying without faces
# Converting:  99% 4080/4112 [35:48<00:16,  1.90it/s]
#
# no faces found for 04081.png, copying without faces
#
#
# no faces found for 04082.png, copying without faces
# Converting:  99% 4082/4112 [35:48<00:15,  1.90it/s]
#
# no faces found for 04083.png, copying without faces
#
#
# no faces found for 04084.png, copying without faces
# Converting:  99% 4084/4112 [35:48<00:14,  1.90it/s]
#
# no faces found for 04085.png, copying without faces
#
#
# no faces found for 04086.png, copying without faces
# Converting:  99% 4086/4112 [35:48<00:13,  1.90it/s]
#
# no faces found for 04087.png, copying without faces
#
#
# no faces found for 04088.png, copying without faces
# Converting:  99% 4088/4112 [35:48<00:12,  1.90it/s]
#
# no faces found for 04089.png, copying without faces
#
#
# no faces found for 04090.png, copying without faces
# Converting:  99% 4090/4112 [35:48<00:11,  1.90it/s]
#
# no faces found for 04091.png, copying without faces
#
#
# no faces found for 04092.png, copying without faces
# Converting: 100% 4092/4112 [35:48<00:10,  1.90it/s]
#
# no faces found for 04093.png, copying without faces
#
#
# no faces found for 04094.png, copying without faces
# Converting: 100% 4094/4112 [35:48<00:09,  1.91it/s]
#
# no faces found for 04095.png, copying without faces
#
#
# no faces found for 04096.png, copying without faces
# Converting: 100% 4096/4112 [35:48<00:08,  1.91it/s]
#
# no faces found for 04097.png, copying without faces
#
#
# no faces found for 04098.png, copying without faces
# Converting: 100% 4098/4112 [35:48<00:07,  1.91it/s]
#
# no faces found for 04099.png, copying without faces
#
#
# no faces found for 04100.png, copying without faces
# Converting: 100% 4099/4112 [35:49<00:06,  1.91it/s]
#
# no faces found for 04101.png, copying without faces
# Converting: 100% 4100/4112 [35:49<00:06,  1.91it/s]
#
# no faces found for 04102.png, copying without faces
# Converting: 100% 4102/4112 [35:49<00:05,  1.91it/s]
#
# no faces found for 04103.png, copying without faces
#
#
# no faces found for 04104.png, copying without faces
# Converting: 100% 4104/4112 [35:49<00:04,  1.91it/s]
#
# no faces found for 04105.png, copying without faces
#
#
# no faces found for 04106.png, copying without faces
# Converting: 100% 4105/4112 [35:49<00:03,  1.91it/s]
#
# no faces found for 04107.png, copying without faces
# Converting: 100% 4106/4112 [35:49<00:03,  1.91it/s]
#
# no faces found for 04108.png, copying without faces
# Converting: 100% 4107/4112 [35:49<00:02,  1.91it/s]
#
# no faces found for 04109.png, copying without faces
# Converting: 100% 4108/4112 [35:49<00:02,  1.91it/s]
#
# no faces found for 04110.png, copying without faces
# Converting: 100% 4109/4112 [35:49<00:01,  1.91it/s]
#
# no faces found for 04111.png, copying without faces
# Converting: 100% 4110/4112 [35:49<00:01,  1.91it/s]
#
# no faces found for 04112.png, copying without faces
# Converting: 100% 4112/4112 [35:49<00:00,  1.91it/s]
# Done.
# ffmpeg version 3.4.6-0ubuntu0.18.04.1 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.18.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2pipe, from 'pipe:':
#   Duration: N/A, bitrate: N/A
#     Stream #0:0: Video: png, rgb24(pc), 1920x1080, 30 fps, 30 tbr, 30 tbn, 30 tbc
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from '/content/workspace/data_dst.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp41isom
#     creation_time   : 2019-08-11T17:31:58.000000Z
#   Duration: 00:02:17.11, start: 0.000000, bitrate: 4355 kb/s
#     Stream #1:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p, 1920x1080 [SAR 1:1 DAR 16:9], 4157 kb/s, 30 fps, 30 tbr, 30k tbn, 60 tbc (default)
#     Metadata:
#       creation_time   : 2020-03-09T15:24:29.000000Z
#       handler_name    : VideoHandler
#       encoder         : AVC Coding
#     Stream #1:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 196 kb/s (default)
#     Metadata:
#       creation_time   : 2020-03-09T15:24:29.000000Z
#       handler_name    : SoundHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
#   Stream #1:1 -> #0:1 (aac (native) -> aac (native))
# [libx264 @ 0x564b2e9c6000] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x564b2e9c6000] profile High, level 4.1
# [libx264 @ 0x564b2e9c6000] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=abr mbtree=1 bitrate=16000 ratetol=1.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/content/workspace/eun_beau2_DF_seamless_15_250.mp4':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p(progressive), 1920x1080, q=-1--1, 16000 kb/s, 30 fps, 15360 tbn, 30 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/16000000 buffer size: 0 vbv_delay: -1
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 192 kb/s (default)
#     Metadata:
#       creation_time   : 2020-03-09T15:24:29.000000Z
#       handler_name    : SoundHandler
#       encoder         : Lavc57.107.100 aac
# [image2pipe @ 0x564b2e8e8000] Thread message queue blocking; consider raising the thread_queue_size option (current value: 8)

# %%
#@title Clone or pull DeepFaceLab from Github

Mode = "clone" #@param ["clone", "pull"]

from pathlib import Path
if (Mode == "clone"):
  # !git clone https://github.com/iperov/DeepFaceLab.git --branch DFL-1.0
else:
  # %cd /content/DeepFaceLab
  # !git pull

# !pip install -r /content/DeepFaceLab/requirements-colab.txt
# !pip install --upgrade scikit-image
# !apt-get install cuda-10-0

if not Path("/content/pretrain").exists():
  # !wget -q --no-check-certificate -r 'https://github.com/chervonij/DFL-Colab/releases/download/pretrain-CelebA/pretrain_CelebA.zip' -O pretrain_CelebA.zip
  # !mkdir /content/pretrain
  # !unzip -q /content/pretrain_CelebA.zip -d /content/pretrain/
  # !rm /content/pretrain_CelebA.zip

print("Done!")

# %%
#@title Import from Drive

Mode = "workspace" #@param ["workspace", "data_src", "data_dst", "data_src aligned", "data_dst aligned", "models"]
Archive_name = "workspace.zip" #@param {type:"string"}

#Mount Google Drive as folder
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

def zip_and_copy(path, mode):
  unzip_cmd=" -q "+Archive_name
  
  # %cd $path
  copy_cmd = "/content/drive/My\ Drive/"+Archive_name+" "+path
  # !cp $copy_cmd
  # !unzip $unzip_cmd    
  # !rm $Archive_name

if Mode == "workspace":
  zip_and_copy("/content", "workspace")
elif Mode == "data_src":
  zip_and_copy("/content/workspace", "data_src")
elif Mode == "data_dst":
  zip_and_copy("/content/workspace", "data_dst")
elif Mode == "data_src aligned":
  zip_and_copy("/content/workspace/data_src", "aligned")
elif Mode == "data_dst aligned":
  zip_and_copy("/content/workspace/data_dst", "aligned")
elif Mode == "models":
  zip_and_copy("/content/workspace", "model")
  
print("Done!")

# %%
#@title Extract frames
Video = "data_dst" #@param ["data_src", "data_dst"]

# %cd "/content"

cmd = "DeepFaceLab/main.py videoed extract-video"

if Video == "data_dst":
  cmd+= " --input-file workspace/data_dst.* --output-dir workspace/data_dst/"
else:
  cmd+= " --input-file workspace/data_src.* --output-dir workspace/data_src/"
  
# !python $cmd

# %%
path2 = "/content/workspace/" + FileName  + ".mp4 /content/drive/My\ Drive/"

# !cp $path2
